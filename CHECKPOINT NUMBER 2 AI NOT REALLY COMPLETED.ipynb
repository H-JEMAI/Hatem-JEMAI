# %%
## linear algebra
import numpy as np 

# data processing
import pandas as pd 


# data visualization
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("titanic.csv")
print(df)
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000    0.0    0.0   24160  211.3375       B5        S    2
# 1       male   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11
# 2     female   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1305  female      NaN    1.0    0.0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000    0.0    0.0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000    0.0    0.0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000    0.0    0.0  315082    7.8750      NaN        S  NaN
# 1309     NaN      NaN    NaN    NaN     NaN       NaN      NaN      NaN  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
# 1309    NaN                              NaN
#
# [1310 rows x 14 columns]

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
# pclass       1309 non-null float64
# survived     1309 non-null float64
# name         1309 non-null object
# sex          1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null float64
# parch        1309 non-null float64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(7), object(7)
# memory usage: 107.5+ KB

# %%
df.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5     1.0       1.0                              Anderson, Mr. Harry    male
# 6     1.0       1.0                Andrews, Miss. Kornelia Theodosia  female
# 7     1.0       0.0                           Andrews, Mr. Thomas Jr    male
# 8     1.0       1.0    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9     1.0       0.0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0     24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0    113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0    113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0    113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0    113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0000    0.0    0.0     19952   26.5500      E12        S    3    NaN
# 6  63.0000    1.0    0.0     13502   77.9583       D7        S   10    NaN
# 7  39.0000    0.0    0.0    112050    0.0000      A36        S  NaN    NaN
# 8  53.0000    2.0    0.0     11769   51.4792     C101        S    D    NaN
# 9  71.0000    0.0    0.0  PC 17609   49.5042      NaN        C  NaN   22.0
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 6                       Hudson, NY
# 7                      Belfast, NI
# 8              Bayside, Queens, NY
# 9              Montevideo, Uruguay

# %%
 

df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# Algorithms
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis  import LinearDiscriminantAnalysis
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
print(df.head(8))
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5     1.0       1.0                              Anderson, Mr. Harry    male
# 6     1.0       1.0                Andrews, Miss. Kornelia Theodosia  female
# 7     1.0       0.0                           Andrews, Mr. Thomas Jr    male
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0000    0.0    0.0   19952   26.5500      E12        S    3    NaN
# 6  63.0000    1.0    0.0   13502   77.9583       D7        S   10    NaN
# 7  39.0000    0.0    0.0  112050    0.0000      A36        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 6                       Hudson, NY
# 7                      Belfast, NI

# %%
print(df.head().isnull())
# Out:
#    pclass  survived   name    sex    age  sibsp  parch  ticket   fare  cabin  \
# 0   False     False  False  False  False  False  False   False  False  False
# 1   False     False  False  False  False  False  False   False  False  False
# 2   False     False  False  False  False  False  False   False  False  False
# 3   False     False  False  False  False  False  False   False  False  False
# 4   False     False  False  False  False  False  False   False  False  False
#
#    embarked   boat   body  home.dest
# 0     False  False   True      False
# 1     False  False   True      False
# 2     False   True   True      False
# 3     False   True  False      False
# 4     False   True   True      False

# %%
print(df.isnull())
# Out:
#       pclass  survived   name    sex    age  sibsp  parch  ticket   fare  \
# 0      False     False  False  False  False  False  False   False  False
# 1      False     False  False  False  False  False  False   False  False
# 2      False     False  False  False  False  False  False   False  False
# 3      False     False  False  False  False  False  False   False  False
# 4      False     False  False  False  False  False  False   False  False
# ...      ...       ...    ...    ...    ...    ...    ...     ...    ...
# 1305   False     False  False  False   True  False  False   False  False
# 1306   False     False  False  False  False  False  False   False  False
# 1307   False     False  False  False  False  False  False   False  False
# 1308   False     False  False  False  False  False  False   False  False
# 1309    True      True   True   True   True   True   True    True   True
#
#       cabin  embarked   boat   body  home.dest
# 0     False     False  False   True      False
# 1     False     False  False   True      False
# 2     False     False   True   True      False
# 3     False     False   True  False      False
# 4     False     False   True   True      False
# ...     ...       ...    ...    ...        ...
# 1305   True     False   True   True       True
# 1306   True     False   True  False       True
# 1307   True     False   True   True       True
# 1308   True     False   True   True       True
# 1309   True      True   True   True       True
#
# [1310 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 3869

# %%
print(df['ticket'].tail(20).isnull())
# Out:
# 1290    False
# 1291    False
# 1292    False
# 1293    False
# 1294    False
# 1295    False
# 1296    False
# 1297    False
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# 1303    False
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# 1309     True
# Name: ticket, dtype: bool

# %%
df = df.drop('name',axis = 1)

# %%
df.tail()
# Out:
#       pclass  survived     sex   age  sibsp  parch  ticket     fare cabin  \
# 1305     3.0       0.0  female   NaN    1.0    0.0    2665  14.4542   NaN
# 1306     3.0       0.0    male  26.5    0.0    0.0    2656   7.2250   NaN
# 1307     3.0       0.0    male  27.0    0.0    0.0    2670   7.2250   NaN
# 1308     3.0       0.0    male  29.0    0.0    0.0  315082   7.8750   NaN
# 1309     NaN       NaN     NaN   NaN    NaN    NaN     NaN      NaN   NaN
#
#      embarked boat   body home.dest
# 1305        C  NaN    NaN       NaN
# 1306        C  NaN  304.0       NaN
# 1307        C  NaN    NaN       NaN
# 1308        S  NaN    NaN       NaN
# 1309      NaN  NaN    NaN       NaN

# %%
#insert values into missing ages 
    
df['age'].fillna(df['age'].mean(),inplace = True)

# %%
df.isnull().sum().sum()
# Out:
# 3604

# %%
df.dropna(axis = 1 , how = 'all')
df.dropna(axis = 0 , how = 'all')

print (df)
df.isnull().sum().sum()
# Out:
#       pclass  survived     sex        age  sibsp  parch  ticket      fare  \
# 0        1.0       1.0  female  29.000000    0.0    0.0   24160  211.3375
# 1        1.0       1.0    male   0.916700    1.0    2.0  113781  151.5500
# 2        1.0       0.0  female   2.000000    1.0    2.0  113781  151.5500
# 3        1.0       0.0    male  30.000000    1.0    2.0  113781  151.5500
# 4        1.0       0.0  female  25.000000    1.0    2.0  113781  151.5500
# ...      ...       ...     ...        ...    ...    ...     ...       ...
# 1305     3.0       0.0  female  29.881135    1.0    0.0    2665   14.4542
# 1306     3.0       0.0    male  26.500000    0.0    0.0    2656    7.2250
# 1307     3.0       0.0    male  27.000000    0.0    0.0    2670    7.2250
# 1308     3.0       0.0    male  29.000000    0.0    0.0  315082    7.8750
# 1309     NaN       NaN     NaN  29.881135    NaN    NaN     NaN       NaN
#
#         cabin embarked boat   body                        home.dest
# 0          B5        S    2    NaN                     St Louis, MO
# 1     C22 C26        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2     C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3     C22 C26        S  NaN  135.0  Montreal, PQ / Chesterville, ON
# 4     C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# ...       ...      ...  ...    ...                              ...
# 1305      NaN        C  NaN    NaN                              NaN
# 1306      NaN        C  NaN  304.0                              NaN
# 1307      NaN        C  NaN    NaN                              NaN
# 1308      NaN        S  NaN    NaN                              NaN
# 1309      NaN      NaN  NaN    NaN                              NaN
#
# [1310 rows x 13 columns]
# 3604

# %%
df.dropna(axis = 0 , how = 'all')

print (df)
df.isnull().sum().sum()
# Out:
#       pclass  survived     sex        age  sibsp  parch  ticket      fare  \
# 0        1.0       1.0  female  29.000000    0.0    0.0   24160  211.3375
# 1        1.0       1.0    male   0.916700    1.0    2.0  113781  151.5500
# 2        1.0       0.0  female   2.000000    1.0    2.0  113781  151.5500
# 3        1.0       0.0    male  30.000000    1.0    2.0  113781  151.5500
# 4        1.0       0.0  female  25.000000    1.0    2.0  113781  151.5500
# ...      ...       ...     ...        ...    ...    ...     ...       ...
# 1305     3.0       0.0  female  29.881135    1.0    0.0    2665   14.4542
# 1306     3.0       0.0    male  26.500000    0.0    0.0    2656    7.2250
# 1307     3.0       0.0    male  27.000000    0.0    0.0    2670    7.2250
# 1308     3.0       0.0    male  29.000000    0.0    0.0  315082    7.8750
# 1309     NaN       NaN     NaN  29.881135    NaN    NaN     NaN       NaN
#
#         cabin embarked boat   body                        home.dest
# 0          B5        S    2    NaN                     St Louis, MO
# 1     C22 C26        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2     C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3     C22 C26        S  NaN  135.0  Montreal, PQ / Chesterville, ON
# 4     C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# ...       ...      ...  ...    ...                              ...
# 1305      NaN        C  NaN    NaN                              NaN
# 1306      NaN        C  NaN  304.0                              NaN
# 1307      NaN        C  NaN    NaN                              NaN
# 1308      NaN        S  NaN    NaN                              NaN
# 1309      NaN      NaN  NaN    NaN                              NaN
#
# [1310 rows x 13 columns]
# 3604

# %%
df.dropna(thresh=7)
# Out:
#       pclass  survived     sex        age  sibsp  parch  ticket      fare  \
# 0        1.0       1.0  female  29.000000    0.0    0.0   24160  211.3375
# 1        1.0       1.0    male   0.916700    1.0    2.0  113781  151.5500
# 2        1.0       0.0  female   2.000000    1.0    2.0  113781  151.5500
# 3        1.0       0.0    male  30.000000    1.0    2.0  113781  151.5500
# 4        1.0       0.0  female  25.000000    1.0    2.0  113781  151.5500
# ...      ...       ...     ...        ...    ...    ...     ...       ...
# 1304     3.0       0.0  female  14.500000    1.0    0.0    2665   14.4542
# 1305     3.0       0.0  female  29.881135    1.0    0.0    2665   14.4542
# 1306     3.0       0.0    male  26.500000    0.0    0.0    2656    7.2250
# 1307     3.0       0.0    male  27.000000    0.0    0.0    2670    7.2250
# 1308     3.0       0.0    male  29.000000    0.0    0.0  315082    7.8750
#
#         cabin embarked boat   body                        home.dest
# 0          B5        S    2    NaN                     St Louis, MO
# 1     C22 C26        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2     C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3     C22 C26        S  NaN  135.0  Montreal, PQ / Chesterville, ON
# 4     C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# ...       ...      ...  ...    ...                              ...
# 1304      NaN        C  NaN  328.0                              NaN
# 1305      NaN        C  NaN    NaN                              NaN
# 1306      NaN        C  NaN  304.0                              NaN
# 1307      NaN        C  NaN    NaN                              NaN
# 1308      NaN        S  NaN    NaN                              NaN
#
# [1309 rows x 13 columns]

# %%
df.head(20)
# Out:
#     pclass  survived     sex        age  sibsp  parch    ticket      fare  \
# 0      1.0       1.0  female  29.000000    0.0    0.0     24160  211.3375
# 1      1.0       1.0    male   0.916700    1.0    2.0    113781  151.5500
# 2      1.0       0.0  female   2.000000    1.0    2.0    113781  151.5500
# 3      1.0       0.0    male  30.000000    1.0    2.0    113781  151.5500
# 4      1.0       0.0  female  25.000000    1.0    2.0    113781  151.5500
# 5      1.0       1.0    male  48.000000    0.0    0.0     19952   26.5500
# 6      1.0       1.0  female  63.000000    1.0    0.0     13502   77.9583
# 7      1.0       0.0    male  39.000000    0.0    0.0    112050    0.0000
# 8      1.0       1.0  female  53.000000    2.0    0.0     11769   51.4792
# 9      1.0       0.0    male  71.000000    0.0    0.0  PC 17609   49.5042
# 10     1.0       0.0    male  47.000000    1.0    0.0  PC 17757  227.5250
# 11     1.0       1.0  female  18.000000    1.0    0.0  PC 17757  227.5250
# 12     1.0       1.0  female  24.000000    0.0    0.0  PC 17477   69.3000
# 13     1.0       1.0  female  26.000000    0.0    0.0     19877   78.8500
# 14     1.0       1.0    male  80.000000    0.0    0.0     27042   30.0000
# 15     1.0       0.0    male  29.881135    0.0    0.0  PC 17318   25.9250
# 16     1.0       0.0    male  24.000000    0.0    1.0  PC 17558  247.5208
# 17     1.0       1.0  female  50.000000    0.0    1.0  PC 17558  247.5208
# 18     1.0       1.0  female  32.000000    0.0    0.0     11813   76.2917
# 19     1.0       0.0    male  36.000000    0.0    0.0     13050   75.2417
#
#       cabin embarked boat   body                        home.dest
# 0        B5        S    2    NaN                     St Louis, MO
# 1   C22 C26        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2   C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3   C22 C26        S  NaN  135.0  Montreal, PQ / Chesterville, ON
# 4   C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 5       E12        S    3    NaN                     New York, NY
# 6        D7        S   10    NaN                       Hudson, NY
# 7       A36        S  NaN    NaN                      Belfast, NI
# 8      C101        S    D    NaN              Bayside, Queens, NY
# 9       NaN        C  NaN   22.0              Montevideo, Uruguay
# 10  C62 C64        C  NaN  124.0                     New York, NY
# 11  C62 C64        C    4    NaN                     New York, NY
# 12      B35        C    9    NaN                    Paris, France
# 13      NaN        S    6    NaN                              NaN
# 14      A23        S    B    NaN                    Hessle, Yorks
# 15      NaN        S  NaN    NaN                     New York, NY
# 16  B58 B60        C  NaN    NaN                     Montreal, PQ
# 17  B58 B60        C    6    NaN                     Montreal, PQ
# 18      D15        C    8    NaN                              NaN
# 19       C6        C    A    NaN                     Winnipeg, MN

# %%
df['cabin'].fillna('0',inplace = True)
df.isnull().sum().sum()
# Out:
# 2589

# %%
df['sex'].fillna('0',inplace = True)
df.isnull().sum().sum()
# Out:
# 2588

# %%
df['boat'].fillna('0',inplace = True)
df.isnull().sum().sum()
df.head(20)
# Out:
#     pclass  survived     sex        age  sibsp  parch    ticket      fare  \
# 0      1.0       1.0  female  29.000000    0.0    0.0     24160  211.3375
# 1      1.0       1.0    male   0.916700    1.0    2.0    113781  151.5500
# 2      1.0       0.0  female   2.000000    1.0    2.0    113781  151.5500
# 3      1.0       0.0    male  30.000000    1.0    2.0    113781  151.5500
# 4      1.0       0.0  female  25.000000    1.0    2.0    113781  151.5500
# 5      1.0       1.0    male  48.000000    0.0    0.0     19952   26.5500
# 6      1.0       1.0  female  63.000000    1.0    0.0     13502   77.9583
# 7      1.0       0.0    male  39.000000    0.0    0.0    112050    0.0000
# 8      1.0       1.0  female  53.000000    2.0    0.0     11769   51.4792
# 9      1.0       0.0    male  71.000000    0.0    0.0  PC 17609   49.5042
# 10     1.0       0.0    male  47.000000    1.0    0.0  PC 17757  227.5250
# 11     1.0       1.0  female  18.000000    1.0    0.0  PC 17757  227.5250
# 12     1.0       1.0  female  24.000000    0.0    0.0  PC 17477   69.3000
# 13     1.0       1.0  female  26.000000    0.0    0.0     19877   78.8500
# 14     1.0       1.0    male  80.000000    0.0    0.0     27042   30.0000
# 15     1.0       0.0    male  29.881135    0.0    0.0  PC 17318   25.9250
# 16     1.0       0.0    male  24.000000    0.0    1.0  PC 17558  247.5208
# 17     1.0       1.0  female  50.000000    0.0    1.0  PC 17558  247.5208
# 18     1.0       1.0  female  32.000000    0.0    0.0     11813   76.2917
# 19     1.0       0.0    male  36.000000    0.0    0.0     13050   75.2417
#
#       cabin embarked boat   body                        home.dest
# 0        B5        S    2    NaN                     St Louis, MO
# 1   C22 C26        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2   C22 C26        S    0    NaN  Montreal, PQ / Chesterville, ON
# 3   C22 C26        S    0  135.0  Montreal, PQ / Chesterville, ON
# 4   C22 C26        S    0    NaN  Montreal, PQ / Chesterville, ON
# 5       E12        S    3    NaN                     New York, NY
# 6        D7        S   10    NaN                       Hudson, NY
# 7       A36        S    0    NaN                      Belfast, NI
# 8      C101        S    D    NaN              Bayside, Queens, NY
# 9         0        C    0   22.0              Montevideo, Uruguay
# 10  C62 C64        C    0  124.0                     New York, NY
# 11  C62 C64        C    4    NaN                     New York, NY
# 12      B35        C    9    NaN                    Paris, France
# 13        0        S    6    NaN                              NaN
# 14      A23        S    B    NaN                    Hessle, Yorks
# 15        0        S    0    NaN                     New York, NY
# 16  B58 B60        C    0    NaN                     Montreal, PQ
# 17  B58 B60        C    6    NaN                     Montreal, PQ
# 18      D15        C    8    NaN                              NaN
# 19       C6        C    A    NaN                     Winnipeg, MN

# %%
df.isnull().sum().sum()
# Out:
# 1764

# %%
df.isnull().sum()
# Out:
# pclass          1
# survived        1
# sex             0
# age             0
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin           0
# embarked        3
# boat            0
# body         1189
# home.dest     565
# dtype: int64

# %%
print(df['ticket'])
# Out:
# 0        24160
# 1       113781
# 2       113781
# 3       113781
# 4       113781
#          ...
# 1305      2665
# 1306      2656
# 1307      2670
# 1308    315082
# 1309       NaN
# Name: ticket, Length: 1310, dtype: object

# %%
print(df['ticket'].head(12).isnull())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# Name: ticket, dtype: bool

# %%
print(df['ticket'].isnull())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# 1309     True
# Name: ticket, Length: 1310, dtype: bool

# %%
print(df['ticket'].tail(33).isnull())
# Out:
# 1277    False
# 1278    False
# 1279    False
# 1280    False
# 1281    False
# 1282    False
# 1283    False
# 1284    False
# 1285    False
# 1286    False
# 1287    False
# 1288    False
# 1289    False
# 1290    False
# 1291    False
# 1292    False
# 1293    False
# 1294    False
# 1295    False
# 1296    False
# 1297    False
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# 1303    False
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# 1309     True
# Name: ticket, dtype: bool

# %%
df.isnull().sum()
# Out:
# pclass          1
# survived        1
# sex             0
# age             0
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin           0
# embarked        3
# boat            0
# body         1189
# home.dest     565
# dtype: int64

# %%
df .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 13 columns):
# pclass       1309 non-null float64
# survived     1309 non-null float64
# sex          1310 non-null object
# age          1310 non-null float64
# sibsp        1309 non-null float64
# parch        1309 non-null float64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        1310 non-null object
# embarked     1307 non-null object
# boat         1310 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(7), object(6)
# memory usage: 102.4+ KB

# %%
df.isnull().sum().sum()
df.isnull().sum()
# Out:
# pclass          1
# survived        1
# sex             0
# age             0
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin           0
# embarked        3
# boat            0
# body         1189
# home.dest     565
# dtype: int64

# %%
df['parch'].fillna('0',inplace = True)     
df['sibsp'].fillna('0',inplace = True)   
df['embarked'].fillna('0',inplace = True)
df['fare'].fillna('0',inplace = True)
df['body'].fillna('0',inplace = True)
df['pclass'].fillna('0',inplace = True)
df['fare'].fillna('0',inplace = True)

# %%
df.isnull().sum()
# Out:
# pclass         0
# survived       1
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         1
# fare           0
# cabin          0
# embarked       0
# boat           0
# body           0
# home.dest    565
# dtype: int64

# %%
df['cabin'].fillna('0',inplace = True)

# %%
df.isnull().sum().sum()
# Out:
# 567

# %%
df = df.drop ('home.dest',axis = 1)

# %%
df.isnull().sum().sum()
# Out:
# 2

# %%
df.isnull().sum()
# Out:
# pclass      0
# survived    1
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      1
# fare        0
# cabin       0
# embarked    0
# boat        0
# body        0
# dtype: int64

# %%
df['ticket'].fillna('0',inplace = True)
df['survived'].fillna('0',inplace = True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.tail()
# Out:
#      pclass survived     sex        age sibsp parch  ticket     fare cabin  \
# 1305      3        0  female  29.881135     1     0    2665  14.4542     0
# 1306      3        0    male  26.500000     0     0    2656    7.225     0
# 1307      3        0    male  27.000000     0     0    2670    7.225     0
# 1308      3        0    male  29.000000     0     0  315082    7.875     0
# 1309      0        0       0  29.881135     0     0       0        0     0
#
#      embarked boat body
# 1305        C    0    0
# 1306        C    0  304
# 1307        C    0    0
# 1308        S    0    0
# 1309        0    0    0

# %%
from sklearn.preprocessing  import LabelEncoder

encoder = LabelEncoder()

df['sex']= encoder.fit_transform (df['sex'])
df['cabin']= encoder.fit_transform (df['cabin'])
df['embarked']= encoder.fit_transform (df['embarked'])



df
# Out:
#      pclass survived  sex        age sibsp parch  ticket     fare  cabin  \
# 0         1        1    1  29.000000     0     0   24160  211.338     44
# 1         1        1    2   0.916700     1     2  113781   151.55     80
# 2         1        0    1   2.000000     1     2  113781   151.55     80
# 3         1        0    2  30.000000     1     2  113781   151.55     80
# 4         1        0    1  25.000000     1     2  113781   151.55     80
# ...     ...      ...  ...        ...   ...   ...     ...      ...    ...
# 1305      3        0    1  29.881135     1     0    2665  14.4542      0
# 1306      3        0    2  26.500000     0     0    2656    7.225      0
# 1307      3        0    2  27.000000     0     0    2670    7.225      0
# 1308      3        0    2  29.000000     0     0  315082    7.875      0
# 1309      0        0    0  29.881135     0     0       0        0      0
#
#       embarked boat body
# 0            3    2    0
# 1            3   11    0
# 2            3    0    0
# 3            3    0  135
# 4            3    0    0
# ...        ...  ...  ...
# 1305         1    0    0
# 1306         1    0  304
# 1307         1    0    0
# 1308         3    0    0
# 1309         0    0    0
#
# [1310 rows x 12 columns]

# %%
df['ticket']= encoder.fit_transform (df['ticket'])

# %%
df['boat']= encoder.fit_transform (df['boat'])

# %%
df.head()
# Out:
#   pclass survived  sex      age sibsp parch  ticket     fare  cabin  embarked  \
# 0      1        1    1  29.0000     0     0     188  211.338     44         3
# 1      1        1    2   0.9167     1     2      50   151.55     80         3
# 2      1        0    1   2.0000     1     2      50   151.55     80         3
# 3      1        0    2  30.0000     1     2      50   151.55     80         3
# 4      1        0    1  25.0000     1     2      50   151.55     80         3
#
#    boat body
# 0    12    0
# 1     3    0
# 2     0    0
# 3     0  135
# 4     0    0

# %%
df.round(1)
# Out:
#      pclass survived  sex   age sibsp parch  ticket     fare  cabin  embarked  \
# 0         1        1    1  29.0     0     0     188  211.338     44         3
# 1         1        1    2   0.9     1     2      50   151.55     80         3
# 2         1        0    1   2.0     1     2      50   151.55     80         3
# 3         1        0    2  30.0     1     2      50   151.55     80         3
# 4         1        0    1  25.0     1     2      50   151.55     80         3
# ...     ...      ...  ...   ...   ...   ...     ...      ...    ...       ...
# 1305      3        0    1  29.9     1     0     260  14.4542      0         1
# 1306      3        0    2  26.5     0     0     251    7.225      0         1
# 1307      3        0    2  27.0     0     0     265    7.225      0         1
# 1308      3        0    2  29.0     0     0     347    7.875      0         3
# 1309      0        0    0  29.9     0     0       0        0      0         0
#
#       boat body
# 0       12    0
# 1        3    0
# 2        0    0
# 3        0  135
# 4        0    0
# ...    ...  ...
# 1305     0    0
# 1306     0  304
# 1307     0    0
# 1308     0    0
# 1309     0    0
#
# [1310 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 12 columns):
# pclass      1310 non-null object
# survived    1310 non-null object
# sex         1310 non-null int32
# age         1310 non-null float64
# sibsp       1310 non-null object
# parch       1310 non-null object
# ticket      1310 non-null int32
# fare        1310 non-null object
# cabin       1310 non-null int32
# embarked    1310 non-null int32
# boat        1310 non-null int32
# body        1310 non-null object
# dtypes: float64(1), int32(5), object(6)
# memory usage: 66.6+ KB

# %%
df.shape
# Out:
# (1310, 12)

# %%
sns.heatmap(df.isna())

# %%
plt.title("histogramm ages")
plt.xlabel('age')
plt.ylabel('Frequency')
df['age'].plot.hist()

# %%
df = pd.read_csv("titanic.csv")
plt .title('histogramme fare')
plt.xlabel('fare')
plt.ylabel('Frequency')
df['fare'].plot.hist()

# %%
plt .title('histogramme sibsp')
plt.xlabel('sibsp')
plt.ylabel('Frequency')
df['sibsp'].plot.hist()

# %%
plt .title('histogram body')
plt.xlabel('body')
plt.ylabel('Frequency')
df['body'] .plot.hist()

# %%
sns .distplot(df['age'],bins=10,hist=True,kde=True,color='red')

# %%
role = {'sex','sibsp','parch','ticket','fare','cabin','embarked','boat'}


plt .title('bar plot')
plt.xlabel('sex','sibsp','parch','ticket','fare','cabin','embarked','boat')
plt.ylabel(('sex','sibsp','parch','ticket','fare','cabin','embarked','boat') value count')
vc .df['sex','sibsp','parch','ticket','fare','cabin','embarked','boat'] .value_counts
vc.plot.bar(rot=45)
# Out:
#   File "<ipython-input-24-ddcbf4f5499f>", line 6
#     plt.ylabel(('sex','sibsp','parch','ticket','fare','cabin','embarked','boat') value count')
#                                                                                      ^
# SyntaxError: invalid syntax

# %%
df.plot.scatter(x ='sex',y= 'age')

# %%
import seaborn as sns
sns.lmplot(x='sex',y='age',df =new_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-e915499b368b> in <module>
#       1 import seaborn as sns
# ----> 2 sns.lmplot(x='sex',y='age',df =new_df)
#
# NameError: name 'new_df' is not defined

# %%
df.plot.scatter(x ='cabin',y= 'ticket')

# %%
df.plot.scatter(x ='sex',y= 'ticket')

# %%
df.plot.scatter(x ='embarked',y= 'ticket')

# %%
df.plot.scatter(x ='embarked',y= 'boat')

# %%
df.plot.scatter(x ='cabin',y= 'ticket')

# %%
def plot_correlation_map(df):
    
    
# correlation matrix computing
    corr = df.corr()
# MORE THAN ONE GRAPH SHOWN
    s , ax = plt.subplots(figsize =(12,10))
# customized colormap
    cmap = sns.diverging_palette( 220,10,as_cmap =True )
# heatmap and real ratios drawing
    s = sns.heatmap(corr, cmap = cmap,square=True,cbar_kws={'shrink':.9},ax=ax,annot =True, annot_kws ={'fontsize':12 }
)
    
#THIS IS A SHORT PARAGRAPH ABOUT THE FUNCTION 
#in order to dicover new discrete inputs for 
#what we search to target
#the function dummies all the categories and 
# compute a correlation matrix 
# then show a plot or drawing for better understanding to our processed data

# %%
   
    plt.show()
